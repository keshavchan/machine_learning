# %%
# Define functions to connect to Google and change directories
def connectDrive():
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

def changeDirectory(path):
    import os
    original_path = os.getcwd()
    os.chdir(path)
    new_path = os.getcwd()
    print("Original path: ",original_path)
    print("New path: ",new_path)

# Connect to Google Drive
connectDrive()

# Change path
changeDirectory("Machine-Learning-Practice")
# Out:
# Mounted at /content/drive
# Original path:  /content
# New path:  /content/Machine-Learning-Practice

# %%
'''Main'''
import numpy as np
import pandas as pd
import os

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep'''
from sklearn import preprocessing as pp
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report

'''Algos'''
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import lightgbm as lgb

# %%
# Acquire Data
current_path = os.getcwd()
file = os.path.sep.join(['', 'datasets', 'credit_card_data', 'credit_card.csv'])
data = pd.read_csv('/content/drive/MyDrive/Dataset/datasets/credit_card_data/credit_card.csv')

# %%
# Explore Data
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print("Number of fraudulent transactions:", data['Class'].sum())
# Out:
# Number of fraudulent transactions: 492

# %%
nanCounter = np.isnan(data).sum()

# %%
nanCounter
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
distinctCounter = data.apply(lambda x: len(x.unique()))

# %%
distinctCounter
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
# Generate feature matrix and labels array
dataX = data.copy().drop(['Class'],axis=1)
dataY = data['Class'].copy()

# %%
# Feature scaling
featuresToScale = dataX.drop(['Time'],axis=1).columns

# %%
featuresToScale
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
sX = pp.StandardScaler(copy=True)
dataX.loc[:,featuresToScale] = sX.fit_transform(dataX[featuresToScale])
scalingFactors = pd.DataFrame(data=[sX.mean_,sX.scale_],index=['Mean','StDev'],columns=featuresToScale)

# %%
scalingFactors
# Out:
#                  V1            V2            V3            V4            V5  \
# Mean   1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15  9.604066e-16
# StDev  1.958692e+00  1.651306e+00  1.516252e+00  1.415866e+00  1.380244e+00
#
#                  V6            V7            V8            V9           V10  \
# Mean   1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15  2.239053e-15
# StDev  1.332269e+00  1.237091e+00  1.194351e+00  1.098630e+00  1.088848e+00
#
#        ...           V20           V21           V22           V23  \
# Mean   ...  6.406204e-16  1.654067e-16 -3.568593e-16  2.578648e-16
# StDev  ...  7.709237e-01  7.345227e-01  7.257003e-01  6.244592e-01
#
#                 V24           V25           V26           V27           V28  \
# Mean   4.473266e-15  5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16
# StDev  6.056460e-01  5.212772e-01  4.822262e-01  4.036318e-01  3.300827e-01
#
#            Amount
# Mean    88.349619
# StDev  250.119670
#
# [2 rows x 29 columns]

# %%
dataX.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575 -1.506872e-17 -9.580116e-18 -8.622104e-17 -5.189230e-18
# std     47488.145955  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min         0.000000 -2.879855e+01 -4.403529e+01 -3.187173e+01 -4.013919e+00
# 25%     54201.500000 -4.698918e-01 -3.624707e-01 -5.872142e-01 -5.993788e-01
# 50%     84692.000000  9.245351e-03  3.965683e-02  1.186124e-01 -1.401724e-02
# 75%    139320.500000  6.716939e-01  4.867202e-01  6.774569e-01  5.250082e-01
# max    172792.000000  1.253351e+00  1.335775e+01  6.187993e+00  1.191874e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.832046e-17  9.979288e-18  1.237432e-17 -3.193372e-18  7.234983e-19
# std    1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -8.240810e+01 -1.963606e+01 -3.520940e+01 -6.130252e+01 -1.222802e+01
# 25%   -5.010686e-01 -5.766822e-01 -4.478860e-01 -1.746805e-01 -5.853631e-01
# 50%   -3.936682e-02 -2.058046e-01  3.241723e-02  1.871982e-02 -4.681169e-02
# 75%    4.433465e-01  2.991625e-01  4.611107e-01  2.740785e-01  5.435305e-01
# max    2.521413e+01  5.502015e+01  9.747824e+01  1.675153e+01  1.419494e+01
#
#        ...           V20           V21           V22           V23  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ... -1.247411e-18 -3.642440e-18  3.193372e-18  8.781773e-18
# std    ...  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min    ... -7.069146e+01 -4.741907e+01 -1.506565e+01 -7.175446e+01
# 25%    ... -2.746334e-01 -3.109433e-01 -7.473476e-01 -2.591784e-01
# 50%    ... -8.104705e-02 -4.009429e-02  9.345377e-03 -1.792420e-02
# 75%    ...  1.725733e-01  2.537392e-01  7.283360e-01  2.364319e-01
# max    ...  5.113464e+01  3.703471e+01  1.447304e+01  3.607668e+01
#
#                 V24           V25           V26           V27           V28  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.580116e-18 -5.029561e-17  5.887780e-18  2.444925e-18 -7.908585e-18
# std    1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -4.683638e+00 -1.975033e+01 -5.401098e+00 -5.590660e+01 -4.674612e+01
# 25%   -5.854676e-01 -6.084001e-01 -6.780717e-01 -1.755053e-01 -1.604440e-01
# 50%    6.765678e-02  3.183240e-02 -1.081217e-01  3.325174e-03  3.406368e-02
# 75%    7.257153e-01  6.728006e-01  4.996663e-01  2.255648e-01  2.371526e-01
# max    7.569684e+00  1.442532e+01  7.293975e+00  7.831940e+01  1.025434e+02
#
#              Amount
# count  2.848070e+05
# mean   2.913952e-17
# std    1.000002e+00
# min   -3.532294e-01
# 25%   -3.308401e-01
# 50%   -2.652715e-01
# 75%   -4.471707e-02
# max    1.023622e+02
#
# [8 rows x 30 columns]

# %%
correlationMatrix = pd.DataFrame(data=[],index=dataX.columns,columns=dataX.columns)
for i in dataX.columns:
    for j in dataX.columns:
        correlationMatrix.loc[i,j] = np.round(pearsonr(dataX.loc[:,i],dataX.loc[:,j])[0],2)

# %%
correlation_file = os.path.sep.join(['', 'datasets', 'credit_card_data', 'correlationMatrix.csv'])
correlationMatrix.to_csv('/content/Machine-Learning-Practice/datasets/credit_card_data/Keshav_Correlation_Matrix.csv')

# %%
count_classes = pd.value_counts(data['Class'],sort=True).sort_index()
ax = sns.barplot(x=count_classes.index, y=[tuple(count_classes/len(data))[0],tuple(count_classes/len(data))[1]])
ax.set_title('Frequency Percentage by Class')
ax.set_xlabel('Class')
ax.set_ylabel('Frequency Percentage')
# Out:
# Text(0, 0.5, 'Frequency Percentage')

# %% [markdown]
# ## **Model Preparation**

# %%
X_train, X_test, y_train, y_test = train_test_split(dataX,
                                    dataY, test_size=0.33,
                                    random_state=2018, stratify=dataY)

# %%
len(X_train)
# Out:
# 190820

# %%
len(X_test)
# Out:
# 93987

# %%
y_train.sum()/len(y_train)
# Out:
# 0.0017293784718582959

# %%
y_test.sum()/len(y_test)
# Out:
# 0.0017236426314277506

# %%
k_fold = StratifiedKFold(n_splits=5,shuffle=True,random_state=2018)

# %% [markdown]
# ## **Logistic Regression**

# %%
penalty = 'l2'
C = 1.0
class_weight = 'balanced'
random_state = 2018
solver = 'liblinear'
n_jobs = 1

logReg = LogisticRegression(penalty=penalty, C=C,
            class_weight=class_weight, random_state=random_state,
                            solver=solver, n_jobs=n_jobs)

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[],
                                        index=y_train.index,columns=[0,1])

model = logReg

for train_index, cv_index in k_fold.split(np.zeros(len(X_train))
                                          ,y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], \
        X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], \
        y_train.iloc[cv_index]

    model.fit(X_train_fold, y_train_fold)
    loglossTraining = log_loss(y_train_fold,
                               model.predict_proba(X_train_fold)[:,1])
    trainingScores.append(loglossTraining)

    predictionsBasedOnKFolds.loc[X_cv_fold.index,:] = \
        model.predict_proba(X_cv_fold)
    loglossCV = log_loss(y_cv_fold,
                         predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
    cvScores.append(loglossCV)

    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)

loglossLogisticRegression = log_loss(y_train,
                                     predictionsBasedOnKFolds.loc[:,1])
print('Logistic Regression Log Loss: ', loglossLogisticRegression)
# Out:
# Training Log Loss:  0.1097775266822775
# CV Log Loss:  0.1089462714626564
# Training Log Loss:  0.10468567281985329
# CV Log Loss:  0.10406909485308571
# Training Log Loss:  0.11567458034386095
# CV Log Loss:  0.11807140224997313
# Training Log Loss:  0.11576500172344195
# CV Log Loss:  0.11832970335597207
# Training Log Loss:  0.09728730784067668
# CV Log Loss:  0.09718131096965464
# Logistic Regression Log Loss:  0.1093195565782684

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLogisticRegression = preds.copy()

# %%
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],
                                                       preds['prediction'])

# %%
average_precision = average_precision_score(preds['trueLabel'],
                                            preds['prediction'])

# %%
plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.74')

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])

# %%
areaUnderROC = auc(fpr, tpr)

# %%
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
          Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## **Random Forests**

# %%
n_estimators = 10
max_features = 'auto'
max_depth = None
min_samples_split = 2
min_samples_leaf = 1
min_weight_fraction_leaf = 0.0
max_leaf_nodes = None
bootstrap = True
oob_score = False
n_jobs = -1
random_state = 2018
class_weight = 'balanced'

RFC = RandomForestClassifier(n_estimators=n_estimators,
        max_features=max_features, max_depth=max_depth,
        min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf,
        min_weight_fraction_leaf=min_weight_fraction_leaf,
        max_leaf_nodes=max_leaf_nodes, bootstrap=bootstrap,
        oob_score=oob_score, n_jobs=n_jobs, random_state=random_state,
        class_weight=class_weight)

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[],
                                        index=y_train.index,columns=[0,1])

model = RFC

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),
                                          y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], \
        X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], \
        y_train.iloc[cv_index]

    model.fit(X_train_fold, y_train_fold)
    loglossTraining = log_loss(y_train_fold, \
                                model.predict_proba(X_train_fold)[:,1])
    trainingScores.append(loglossTraining)

    predictionsBasedOnKFolds.loc[X_cv_fold.index,:] = \
        model.predict_proba(X_cv_fold)
    loglossCV = log_loss(y_cv_fold, \
        predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
    cvScores.append(loglossCV)

    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)

loglossRandomForestsClassifier = log_loss(y_train,
                                          predictionsBasedOnKFolds.loc[:,1])
print('Random Forests Log Loss: ', loglossRandomForestsClassifier)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Training Log Loss:  0.0004566021382939061
# CV Log Loss:  0.009445184300497334
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Training Log Loss:  0.00040829452152382496
# CV Log Loss:  0.013138698546690858
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Training Log Loss:  0.0003885344143032627
# CV Log Loss:  0.011246040772474515
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Training Log Loss:  0.0003910895192488638
# CV Log Loss:  0.006854581867693725
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Training Log Loss:  0.00042118560357489436
# CV Log Loss:  0.014015890608317228
# Random Forests Log Loss:  0.010940079219134731

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsRandomForests = preds.copy()

precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],
                                                       preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],
                                            preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
          Area under the curve = {0:0.2f}'.format(
          areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## **LightGBM**

# %%
params_lightGB = { 'task': 'train', 'application':'binary', 'num_class':1, 'boosting': 'gbdt', 'objective': 'binary', 'metric': 'binary_logloss', 'metric_freq':50, 'is_training_metric':False, 'max_depth':4, 'num_leaves': 31, 'learning_rate': 0.01, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'bagging_seed': 2018, 'verbose': 0, 'num_threads':16 }

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[],
                                index=y_train.index,columns=['prediction'])

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),
                                          y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], \
        X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], \
        y_train.iloc[cv_index]

    lgb_train = lgb.Dataset(X_train_fold, y_train_fold)
    lgb_eval = lgb.Dataset(X_cv_fold, y_cv_fold, reference=lgb_train)
    gbm = lgb.train(params_lightGB, lgb_train, num_boost_round=2000,
                   valid_sets=lgb_eval, early_stopping_rounds=200)

    loglossTraining = log_loss(y_train_fold, \
                gbm.predict(X_train_fold, num_iteration=gbm.best_iteration))
    trainingScores.append(loglossTraining)

    predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'] = \
        gbm.predict(X_cv_fold, num_iteration=gbm.best_iteration)
    loglossCV = log_loss(y_cv_fold, \
        predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'])
    cvScores.append(loglossCV)

    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)

loglossLightGBMGradientBoosting = \
    log_loss(y_train, predictionsBasedOnKFolds.loc[:,'prediction'])
print('LightGBM Gradient Boosting Log Loss: ', loglossLightGBMGradientBoosting)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029360 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.00634115
# Training until validation scores don't improve for 200 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.00627113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.00620105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.00615078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.00609437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.00605299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.00599903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.00594246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.00588891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.0058368
# [11]	valid_0's binary_logloss: 0.00578315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.00573411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.0056854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.0056367
# [15]	valid_0's binary_logloss: 0.0055896
# [16]	valid_0's binary_logloss: 0.00554671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.00550416
# [18]	valid_0's binary_logloss: 0.00546486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.00542391
# [20]	valid_0's binary_logloss: 0.00538498
# [21]	valid_0's binary_logloss: 0.00534793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.00531051
# [23]	valid_0's binary_logloss: 0.00527357
# [24]	valid_0's binary_logloss: 0.00523922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.0052041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.00517227
# [27]	valid_0's binary_logloss: 0.00514085
# [28]	valid_0's binary_logloss: 0.00510751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.0050777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.00504717
# [31]	valid_0's binary_logloss: 0.00501409
# [32]	valid_0's binary_logloss: 0.00498378
# [33]	valid_0's binary_logloss: 0.00495165
# [34]	valid_0's binary_logloss: 0.00492133
# [35]	valid_0's binary_logloss: 0.00489235
# [36]	valid_0's binary_logloss: 0.004863
# [37]	valid_0's binary_logloss: 0.0048367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's binary_logloss: 0.00480865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.00478117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.00475422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.0047283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.0047014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.00467433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.00464879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.00462449
# [46]	valid_0's binary_logloss: 0.00459969
# [47]	valid_0's binary_logloss: 0.00457542
# [48]	valid_0's binary_logloss: 0.00455154
# [49]	valid_0's binary_logloss: 0.00452751
# [50]	valid_0's binary_logloss: 0.00450452
# [51]	valid_0's binary_logloss: 0.00448174
# [52]	valid_0's binary_logloss: 0.00445801
# [53]	valid_0's binary_logloss: 0.00443573
# [54]	valid_0's binary_logloss: 0.00441236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.00439153
# [56]	valid_0's binary_logloss: 0.00436943
# [57]	valid_0's binary_logloss: 0.00434727
# [58]	valid_0's binary_logloss: 0.00432577
# [59]	valid_0's binary_logloss: 0.00430628
# [60]	valid_0's binary_logloss: 0.00428639
# [61]	valid_0's binary_logloss: 0.00426577
# [62]	valid_0's binary_logloss: 0.00425005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's binary_logloss: 0.00423038
# [64]	valid_0's binary_logloss: 0.00421327
# [65]	valid_0's binary_logloss: 0.00419679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's binary_logloss: 0.00417806
# [67]	valid_0's binary_logloss: 0.00416022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.00414217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's binary_logloss: 0.00412562
# [70]	valid_0's binary_logloss: 0.00410906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.00409213
# [72]	valid_0's binary_logloss: 0.00407465
# [73]	valid_0's binary_logloss: 0.00405974
# [74]	valid_0's binary_logloss: 0.00404372
# [75]	valid_0's binary_logloss: 0.00402849
# [76]	valid_0's binary_logloss: 0.00401229
# [77]	valid_0's binary_logloss: 0.00399759
# [78]	valid_0's binary_logloss: 0.00398212
# [79]	valid_0's binary_logloss: 0.00396682
# [80]	valid_0's binary_logloss: 0.00395288
# [81]	valid_0's binary_logloss: 0.0039395
# [82]	valid_0's binary_logloss: 0.00392569
# [83]	valid_0's binary_logloss: 0.0039105
# [84]	valid_0's binary_logloss: 0.0038972
# [85]	valid_0's binary_logloss: 0.00388595
# [86]	valid_0's binary_logloss: 0.00387266
# [87]	valid_0's binary_logloss: 0.00385773
# [88]	valid_0's binary_logloss: 0.00384534
# [89]	valid_0's binary_logloss: 0.00383537
# [90]	valid_0's binary_logloss: 0.00382308
# [91]	valid_0's binary_logloss: 0.00380982
# [92]	valid_0's binary_logloss: 0.00379541
# [93]	valid_0's binary_logloss: 0.00378154
# [94]	valid_0's binary_logloss: 0.00376858
# [95]	valid_0's binary_logloss: 0.00375744
# [96]	valid_0's binary_logloss: 0.00374443
# [97]	valid_0's binary_logloss: 0.00373147
# [98]	valid_0's binary_logloss: 0.00371897
# [99]	valid_0's binary_logloss: 0.00370591
# [100]	valid_0's binary_logloss: 0.00369531
# [101]	valid_0's binary_logloss: 0.00368377
# [102]	valid_0's binary_logloss: 0.00367201
# [103]	valid_0's binary_logloss: 0.00366051
# [104]	valid_0's binary_logloss: 0.00365006
# [105]	valid_0's binary_logloss: 0.00363952
# [106]	valid_0's binary_logloss: 0.00362818
# [107]	valid_0's binary_logloss: 0.00361875
# [108]	valid_0's binary_logloss: 0.00360767
# [109]	valid_0's binary_logloss: 0.00359723
# [110]	valid_0's binary_logloss: 0.00358667
# [111]	valid_0's binary_logloss: 0.00357614
# [112]	valid_0's binary_logloss: 0.00356463
# [113]	valid_0's binary_logloss: 0.00355474
# [114]	valid_0's binary_logloss: 0.00354558
# [115]	valid_0's binary_logloss: 0.00353612
# [116]	valid_0's binary_logloss: 0.0035255
# [117]	valid_0's binary_logloss: 0.00351708
# [118]	valid_0's binary_logloss: 0.00350924
# [119]	valid_0's binary_logloss: 0.00349875
# [120]	valid_0's binary_logloss: 0.00349006
# [121]	valid_0's binary_logloss: 0.00348153
# [122]	valid_0's binary_logloss: 0.00347318
# [123]	valid_0's binary_logloss: 0.00346492
# [124]	valid_0's binary_logloss: 0.00345694
# [125]	valid_0's binary_logloss: 0.0034481
# [126]	valid_0's binary_logloss: 0.00343914
# [127]	valid_0's binary_logloss: 0.00343121
# [128]	valid_0's binary_logloss: 0.00342351
# [129]	valid_0's binary_logloss: 0.0034149
# [130]	valid_0's binary_logloss: 0.00340701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's binary_logloss: 0.00339861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's binary_logloss: 0.00339105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's binary_logloss: 0.00338469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's binary_logloss: 0.00337809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's binary_logloss: 0.0033719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's binary_logloss: 0.00336572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's binary_logloss: 0.00335953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's binary_logloss: 0.00335362
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's binary_logloss: 0.00334701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's binary_logloss: 0.00334077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's binary_logloss: 0.00333338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's binary_logloss: 0.0033263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's binary_logloss: 0.00331833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's binary_logloss: 0.00331063
# [145]	valid_0's binary_logloss: 0.00330324
# [146]	valid_0's binary_logloss: 0.00329605
# [147]	valid_0's binary_logloss: 0.00329007
# [148]	valid_0's binary_logloss: 0.00328433
# [149]	valid_0's binary_logloss: 0.00327801
# [150]	valid_0's binary_logloss: 0.00327118
# [151]	valid_0's binary_logloss: 0.00326444
# [152]	valid_0's binary_logloss: 0.0032572
# [153]	valid_0's binary_logloss: 0.00325128
# [154]	valid_0's binary_logloss: 0.0032455
# [155]	valid_0's binary_logloss: 0.00323937
# [156]	valid_0's binary_logloss: 0.00323473
# [157]	valid_0's binary_logloss: 0.00322917
# [158]	valid_0's binary_logloss: 0.00322359
# [159]	valid_0's binary_logloss: 0.00321872
# [160]	valid_0's binary_logloss: 0.00321287
# [161]	valid_0's binary_logloss: 0.00320782
# [162]	valid_0's binary_logloss: 0.00320206
# [163]	valid_0's binary_logloss: 0.00319661
# [164]	valid_0's binary_logloss: 0.00319094
# [165]	valid_0's binary_logloss: 0.00318656
# [166]	valid_0's binary_logloss: 0.00318159
# [167]	valid_0's binary_logloss: 0.00317689
# [168]	valid_0's binary_logloss: 0.00317164
# [169]	valid_0's binary_logloss: 0.00316694
# [170]	valid_0's binary_logloss: 0.00316272
# [171]	valid_0's binary_logloss: 0.00315795
# [172]	valid_0's binary_logloss: 0.00315434
# [173]	valid_0's binary_logloss: 0.00315023
# [174]	valid_0's binary_logloss: 0.00314598
# [175]	valid_0's binary_logloss: 0.00314111
# [176]	valid_0's binary_logloss: 0.00313729
# [177]	valid_0's binary_logloss: 0.00313366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's binary_logloss: 0.00313003
# [179]	valid_0's binary_logloss: 0.00312632
# [180]	valid_0's binary_logloss: 0.00312223
# [181]	valid_0's binary_logloss: 0.00311726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's binary_logloss: 0.00311379
# [183]	valid_0's binary_logloss: 0.00311004
# [184]	valid_0's binary_logloss: 0.00310672
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's binary_logloss: 0.00310231
# [186]	valid_0's binary_logloss: 0.00309898
# [187]	valid_0's binary_logloss: 0.00309547
# [188]	valid_0's binary_logloss: 0.00309234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's binary_logloss: 0.00308779
# [190]	valid_0's binary_logloss: 0.00308516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.00308104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's binary_logloss: 0.00307664
# [193]	valid_0's binary_logloss: 0.0030732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's binary_logloss: 0.00306971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's binary_logloss: 0.00306593
# [196]	valid_0's binary_logloss: 0.00306369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's binary_logloss: 0.00305955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's binary_logloss: 0.00305578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's binary_logloss: 0.00305267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's binary_logloss: 0.00304912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.00304598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's binary_logloss: 0.00304359
# [203]	valid_0's binary_logloss: 0.00303904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's binary_logloss: 0.00303634
# [205]	valid_0's binary_logloss: 0.00303206
# [206]	valid_0's binary_logloss: 0.0030284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.00302612
# [208]	valid_0's binary_logloss: 0.00302187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's binary_logloss: 0.00301932
# [210]	valid_0's binary_logloss: 0.0030171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's binary_logloss: 0.00301496
# [212]	valid_0's binary_logloss: 0.00301082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's binary_logloss: 0.00300827
# [214]	valid_0's binary_logloss: 0.00300651
# [215]	valid_0's binary_logloss: 0.00300231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's binary_logloss: 0.0029998
# [217]	valid_0's binary_logloss: 0.00299842
# [218]	valid_0's binary_logloss: 0.00299647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's binary_logloss: 0.002994
# [220]	valid_0's binary_logloss: 0.0029931
# [221]	valid_0's binary_logloss: 0.00298848
# [222]	valid_0's binary_logloss: 0.00298761
# [223]	valid_0's binary_logloss: 0.00298465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's binary_logloss: 0.00298237
# [225]	valid_0's binary_logloss: 0.0029812
# [226]	valid_0's binary_logloss: 0.00297793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's binary_logloss: 0.00297575
# [228]	valid_0's binary_logloss: 0.00297505
# [229]	valid_0's binary_logloss: 0.00297155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's binary_logloss: 0.00296995
# [231]	valid_0's binary_logloss: 0.00296876
# [232]	valid_0's binary_logloss: 0.00296541
# [233]	valid_0's binary_logloss: 0.00296439
# [234]	valid_0's binary_logloss: 0.00296084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's binary_logloss: 0.00296033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's binary_logloss: 0.00295849
# [237]	valid_0's binary_logloss: 0.00295489
# [238]	valid_0's binary_logloss: 0.00295408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.00295219
# [240]	valid_0's binary_logloss: 0.00295142
# [241]	valid_0's binary_logloss: 0.00294824
# [242]	valid_0's binary_logloss: 0.00294673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.00294542
# [244]	valid_0's binary_logloss: 0.00294238
# [245]	valid_0's binary_logloss: 0.00294171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's binary_logloss: 0.00293989
# [247]	valid_0's binary_logloss: 0.0029375
# [248]	valid_0's binary_logloss: 0.00293619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.00293377
# [250]	valid_0's binary_logloss: 0.00293203
# [251]	valid_0's binary_logloss: 0.00292904
# [252]	valid_0's binary_logloss: 0.00292783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.00292624
# [254]	valid_0's binary_logloss: 0.00292294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's binary_logloss: 0.00292131
# [256]	valid_0's binary_logloss: 0.00292002
# [257]	valid_0's binary_logloss: 0.0029185
# [258]	valid_0's binary_logloss: 0.00291649
# [259]	valid_0's binary_logloss: 0.00291366
# [260]	valid_0's binary_logloss: 0.00291054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.00290953
# [262]	valid_0's binary_logloss: 0.0029079
# [263]	valid_0's binary_logloss: 0.00290662
# [264]	valid_0's binary_logloss: 0.00290502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's binary_logloss: 0.00290427
# [266]	valid_0's binary_logloss: 0.00290328
# [267]	valid_0's binary_logloss: 0.00290075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.00289997
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's binary_logloss: 0.00289856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.00289779
# [271]	valid_0's binary_logloss: 0.00289547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's binary_logloss: 0.00289482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.00289391
# [274]	valid_0's binary_logloss: 0.00288932
# [275]	valid_0's binary_logloss: 0.00288676
# [276]	valid_0's binary_logloss: 0.00288379
# [277]	valid_0's binary_logloss: 0.00288212
# [278]	valid_0's binary_logloss: 0.00288062
# [279]	valid_0's binary_logloss: 0.00287741
# [280]	valid_0's binary_logloss: 0.00287636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's binary_logloss: 0.00287514
# [282]	valid_0's binary_logloss: 0.00287243
# [283]	valid_0's binary_logloss: 0.0028717
# [284]	valid_0's binary_logloss: 0.00287042
# [285]	valid_0's binary_logloss: 0.00286731
# [286]	valid_0's binary_logloss: 0.00286661
# [287]	valid_0's binary_logloss: 0.00286502
# [288]	valid_0's binary_logloss: 0.00286248
# [289]	valid_0's binary_logloss: 0.0028612
# [290]	valid_0's binary_logloss: 0.00286083
# [291]	valid_0's binary_logloss: 0.00285959
# [292]	valid_0's binary_logloss: 0.00285898
# [293]	valid_0's binary_logloss: 0.00285782
# [294]	valid_0's binary_logloss: 0.00285788
# [295]	valid_0's binary_logloss: 0.00285556
# [296]	valid_0's binary_logloss: 0.00285444
# [297]	valid_0's binary_logloss: 0.00285061
# [298]	valid_0's binary_logloss: 0.00285019
# [299]	valid_0's binary_logloss: 0.00284773
# [300]	valid_0's binary_logloss: 0.00284619
# [301]	valid_0's binary_logloss: 0.00284454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's binary_logloss: 0.00284442
# [303]	valid_0's binary_logloss: 0.00284491
# [304]	valid_0's binary_logloss: 0.00284479
# [305]	valid_0's binary_logloss: 0.00284409
# [306]	valid_0's binary_logloss: 0.0028447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's binary_logloss: 0.00284418
# [308]	valid_0's binary_logloss: 0.00284275
# [309]	valid_0's binary_logloss: 0.00284211
# [310]	valid_0's binary_logloss: 0.00283947
# [311]	valid_0's binary_logloss: 0.00283726
# [312]	valid_0's binary_logloss: 0.00283467
# [313]	valid_0's binary_logloss: 0.00283426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.00283395
# [315]	valid_0's binary_logloss: 0.00283157
# [316]	valid_0's binary_logloss: 0.00283021
# [317]	valid_0's binary_logloss: 0.00282772
# [318]	valid_0's binary_logloss: 0.00282784
# [319]	valid_0's binary_logloss: 0.00282553
# [320]	valid_0's binary_logloss: 0.00282422
# [321]	valid_0's binary_logloss: 0.00282271
# [322]	valid_0's binary_logloss: 0.00281977
# [323]	valid_0's binary_logloss: 0.00281952
# [324]	valid_0's binary_logloss: 0.00281926
# [325]	valid_0's binary_logloss: 0.00281762
# [326]	valid_0's binary_logloss: 0.00281741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.00281711
# [328]	valid_0's binary_logloss: 0.00281551
# [329]	valid_0's binary_logloss: 0.00281417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.0028139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.00281288
# [332]	valid_0's binary_logloss: 0.00281134
# [333]	valid_0's binary_logloss: 0.00280976
# [334]	valid_0's binary_logloss: 0.00280873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's binary_logloss: 0.00280688
# [336]	valid_0's binary_logloss: 0.00280621
# [337]	valid_0's binary_logloss: 0.00280534
# [338]	valid_0's binary_logloss: 0.00280488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.00280385
# [340]	valid_0's binary_logloss: 0.0028031
# [341]	valid_0's binary_logloss: 0.00280214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.00280088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.00280005
# [344]	valid_0's binary_logloss: 0.00279929
# [345]	valid_0's binary_logloss: 0.00279793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's binary_logloss: 0.00279696
# [347]	valid_0's binary_logloss: 0.00279631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.00279515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's binary_logloss: 0.00279436
# [350]	valid_0's binary_logloss: 0.00279479
# [351]	valid_0's binary_logloss: 0.00279419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.00279345
# [353]	valid_0's binary_logloss: 0.0027937
# [354]	valid_0's binary_logloss: 0.00279412
# [355]	valid_0's binary_logloss: 0.00279455
# [356]	valid_0's binary_logloss: 0.00279427
# [357]	valid_0's binary_logloss: 0.00279414
# [358]	valid_0's binary_logloss: 0.00279382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.00279348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.00279292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's binary_logloss: 0.00279201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.00279147
# [363]	valid_0's binary_logloss: 0.00279118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.00279065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's binary_logloss: 0.00279032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.00278995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.00278952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.00278922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.00278832
# [370]	valid_0's binary_logloss: 0.00278635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's binary_logloss: 0.00278576
# [372]	valid_0's binary_logloss: 0.00278579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.0027854
# [374]	valid_0's binary_logloss: 0.00278367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.00278294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.00278262
# [377]	valid_0's binary_logloss: 0.00278305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.00278221
# [379]	valid_0's binary_logloss: 0.00278054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.00277998
# [381]	valid_0's binary_logloss: 0.00277796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.00277552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.00277482
# [384]	valid_0's binary_logloss: 0.00277562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.00277411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.00277384
# [387]	valid_0's binary_logloss: 0.00277435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.00277235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.002771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's binary_logloss: 0.00277031
# [391]	valid_0's binary_logloss: 0.00277021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's binary_logloss: 0.00276992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.00276742
# [394]	valid_0's binary_logloss: 0.00276646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's binary_logloss: 0.00276572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.00276584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.00276533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.00276511
# [399]	valid_0's binary_logloss: 0.00276501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.00276258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's binary_logloss: 0.00276194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's binary_logloss: 0.00276088
# [403]	valid_0's binary_logloss: 0.00276001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's binary_logloss: 0.00275979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's binary_logloss: 0.00275914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's binary_logloss: 0.00275897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's binary_logloss: 0.0027576
# [408]	valid_0's binary_logloss: 0.00275782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's binary_logloss: 0.00275719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's binary_logloss: 0.002757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's binary_logloss: 0.00275792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's binary_logloss: 0.00275721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's binary_logloss: 0.00275599
# [414]	valid_0's binary_logloss: 0.00275496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's binary_logloss: 0.00275541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's binary_logloss: 0.00275495
# [417]	valid_0's binary_logloss: 0.00275378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's binary_logloss: 0.0027531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's binary_logloss: 0.0027519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's binary_logloss: 0.00275203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's binary_logloss: 0.00274971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's binary_logloss: 0.00274849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's binary_logloss: 0.00274897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's binary_logloss: 0.00274854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's binary_logloss: 0.00274791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's binary_logloss: 0.00274671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's binary_logloss: 0.00274658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's binary_logloss: 0.0027454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's binary_logloss: 0.00274566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's binary_logloss: 0.00274544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's binary_logloss: 0.00274427
# [432]	valid_0's binary_logloss: 0.00274526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's binary_logloss: 0.0027448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's binary_logloss: 0.00274433
# [435]	valid_0's binary_logloss: 0.00274276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	valid_0's binary_logloss: 0.00274231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	valid_0's binary_logloss: 0.00274212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's binary_logloss: 0.00274098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's binary_logloss: 0.00274125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's binary_logloss: 0.00274144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's binary_logloss: 0.00274135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	valid_0's binary_logloss: 0.00273968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	valid_0's binary_logloss: 0.00273989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's binary_logloss: 0.00274041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [445]	valid_0's binary_logloss: 0.00274002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's binary_logloss: 0.00273837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's binary_logloss: 0.00273811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [448]	valid_0's binary_logloss: 0.00273683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's binary_logloss: 0.00273574
# [450]	valid_0's binary_logloss: 0.00273599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	valid_0's binary_logloss: 0.00273614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's binary_logloss: 0.00273636
# [453]	valid_0's binary_logloss: 0.00273712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	valid_0's binary_logloss: 0.00273728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [455]	valid_0's binary_logloss: 0.00273628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [456]	valid_0's binary_logloss: 0.00273655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [457]	valid_0's binary_logloss: 0.00273678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's binary_logloss: 0.00273615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459]	valid_0's binary_logloss: 0.00273638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	valid_0's binary_logloss: 0.0027354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [461]	valid_0's binary_logloss: 0.00273571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	valid_0's binary_logloss: 0.00273564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [463]	valid_0's binary_logloss: 0.00273569
# [464]	valid_0's binary_logloss: 0.00273561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [465]	valid_0's binary_logloss: 0.00273385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [466]	valid_0's binary_logloss: 0.00273324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [467]	valid_0's binary_logloss: 0.00273354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [468]	valid_0's binary_logloss: 0.00273379
# [469]	valid_0's binary_logloss: 0.00273431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	valid_0's binary_logloss: 0.0027337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [471]	valid_0's binary_logloss: 0.0027338
# [472]	valid_0's binary_logloss: 0.00273337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [473]	valid_0's binary_logloss: 0.00273203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [474]	valid_0's binary_logloss: 0.00273147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [475]	valid_0's binary_logloss: 0.00273056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [476]	valid_0's binary_logloss: 0.0027305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	valid_0's binary_logloss: 0.00273081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [478]	valid_0's binary_logloss: 0.0027295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	valid_0's binary_logloss: 0.00272938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	valid_0's binary_logloss: 0.00272927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [481]	valid_0's binary_logloss: 0.00272758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	valid_0's binary_logloss: 0.0027267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [483]	valid_0's binary_logloss: 0.00272665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [484]	valid_0's binary_logloss: 0.00272698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [485]	valid_0's binary_logloss: 0.00272726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	valid_0's binary_logloss: 0.00272559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [487]	valid_0's binary_logloss: 0.00272557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [488]	valid_0's binary_logloss: 0.0027256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's binary_logloss: 0.00272507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	valid_0's binary_logloss: 0.00272359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491]	valid_0's binary_logloss: 0.0027227
# [492]	valid_0's binary_logloss: 0.0027211
# [493]	valid_0's binary_logloss: 0.00272173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [494]	valid_0's binary_logloss: 0.00272221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [495]	valid_0's binary_logloss: 0.00272232
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [496]	valid_0's binary_logloss: 0.00272026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	valid_0's binary_logloss: 0.00272037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	valid_0's binary_logloss: 0.00272085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	valid_0's binary_logloss: 0.00272106
# [500]	valid_0's binary_logloss: 0.00272041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	valid_0's binary_logloss: 0.00272055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	valid_0's binary_logloss: 0.00271852
# [503]	valid_0's binary_logloss: 0.00271697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [504]	valid_0's binary_logloss: 0.00271745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [505]	valid_0's binary_logloss: 0.00271731
# [506]	valid_0's binary_logloss: 0.00271624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	valid_0's binary_logloss: 0.00271552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [508]	valid_0's binary_logloss: 0.00271454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [509]	valid_0's binary_logloss: 0.00271474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	valid_0's binary_logloss: 0.00271437
# [511]	valid_0's binary_logloss: 0.00271333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [512]	valid_0's binary_logloss: 0.00271173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [513]	valid_0's binary_logloss: 0.0027121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [514]	valid_0's binary_logloss: 0.00271223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [515]	valid_0's binary_logloss: 0.00271187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [516]	valid_0's binary_logloss: 0.00271201
# [517]	valid_0's binary_logloss: 0.00271112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [518]	valid_0's binary_logloss: 0.00271137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [519]	valid_0's binary_logloss: 0.00271001
# [520]	valid_0's binary_logloss: 0.00270915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [521]	valid_0's binary_logloss: 0.00270834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [522]	valid_0's binary_logloss: 0.00270886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [523]	valid_0's binary_logloss: 0.00270775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [524]	valid_0's binary_logloss: 0.00270735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [525]	valid_0's binary_logloss: 0.0027073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [526]	valid_0's binary_logloss: 0.00270682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [527]	valid_0's binary_logloss: 0.00270627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	valid_0's binary_logloss: 0.00270582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [529]	valid_0's binary_logloss: 0.00270577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [530]	valid_0's binary_logloss: 0.00270577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [531]	valid_0's binary_logloss: 0.00270538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	valid_0's binary_logloss: 0.00270436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [533]	valid_0's binary_logloss: 0.00270433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [534]	valid_0's binary_logloss: 0.00270391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [535]	valid_0's binary_logloss: 0.00270336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [536]	valid_0's binary_logloss: 0.00270364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [537]	valid_0's binary_logloss: 0.00270375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [538]	valid_0's binary_logloss: 0.00270335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [539]	valid_0's binary_logloss: 0.00270113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [540]	valid_0's binary_logloss: 0.00270167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [541]	valid_0's binary_logloss: 0.00270165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [542]	valid_0's binary_logloss: 0.00270127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543]	valid_0's binary_logloss: 0.00270124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [544]	valid_0's binary_logloss: 0.00270072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [545]	valid_0's binary_logloss: 0.00270097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [546]	valid_0's binary_logloss: 0.00270139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	valid_0's binary_logloss: 0.00270151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [548]	valid_0's binary_logloss: 0.00270072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [549]	valid_0's binary_logloss: 0.00269974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	valid_0's binary_logloss: 0.0027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [551]	valid_0's binary_logloss: 0.00270002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	valid_0's binary_logloss: 0.0026991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [553]	valid_0's binary_logloss: 0.00269909
# [554]	valid_0's binary_logloss: 0.00269981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [555]	valid_0's binary_logloss: 0.0026987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [556]	valid_0's binary_logloss: 0.00269892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [557]	valid_0's binary_logloss: 0.00269769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	valid_0's binary_logloss: 0.00269799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [559]	valid_0's binary_logloss: 0.00269812
# [560]	valid_0's binary_logloss: 0.00269883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [561]	valid_0's binary_logloss: 0.00269798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	valid_0's binary_logloss: 0.0026969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	valid_0's binary_logloss: 0.00269713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [564]	valid_0's binary_logloss: 0.00269716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [565]	valid_0's binary_logloss: 0.0026973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [566]	valid_0's binary_logloss: 0.00269714
# [567]	valid_0's binary_logloss: 0.00269672
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [568]	valid_0's binary_logloss: 0.00269699
# [569]	valid_0's binary_logloss: 0.0026966
# [570]	valid_0's binary_logloss: 0.00269662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [571]	valid_0's binary_logloss: 0.00269677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [572]	valid_0's binary_logloss: 0.00269573
# [573]	valid_0's binary_logloss: 0.00269409
# [574]	valid_0's binary_logloss: 0.00269393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [575]	valid_0's binary_logloss: 0.00269346
# [576]	valid_0's binary_logloss: 0.00269421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [577]	valid_0's binary_logloss: 0.00269435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [578]	valid_0's binary_logloss: 0.00269406
# [579]	valid_0's binary_logloss: 0.00269392
# [580]	valid_0's binary_logloss: 0.00269262
# [581]	valid_0's binary_logloss: 0.00269245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [582]	valid_0's binary_logloss: 0.00269176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [583]	valid_0's binary_logloss: 0.00269087
# [584]	valid_0's binary_logloss: 0.00269052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [585]	valid_0's binary_logloss: 0.00268988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	valid_0's binary_logloss: 0.00268889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [587]	valid_0's binary_logloss: 0.00268915
# [588]	valid_0's binary_logloss: 0.00268902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [589]	valid_0's binary_logloss: 0.00268836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [590]	valid_0's binary_logloss: 0.00268819
# ...
# [669]	valid_0's binary_logloss: 0.00360312
# [670]	valid_0's binary_logloss: 0.00360289
# [671]	valid_0's binary_logloss: 0.00360272
# [672]	valid_0's binary_logloss: 0.00360354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [673]	valid_0's binary_logloss: 0.00360309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [674]	valid_0's binary_logloss: 0.00360248
# [675]	valid_0's binary_logloss: 0.00360253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [676]	valid_0's binary_logloss: 0.00360306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [677]	valid_0's binary_logloss: 0.00360319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [678]	valid_0's binary_logloss: 0.00360302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [679]	valid_0's binary_logloss: 0.00360306
# [680]	valid_0's binary_logloss: 0.00360441
# [681]	valid_0's binary_logloss: 0.00360444
# [682]	valid_0's binary_logloss: 0.0036046
# [683]	valid_0's binary_logloss: 0.00360464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [684]	valid_0's binary_logloss: 0.00360452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [685]	valid_0's binary_logloss: 0.00360509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [686]	valid_0's binary_logloss: 0.00360561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [687]	valid_0's binary_logloss: 0.00360599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [688]	valid_0's binary_logloss: 0.00360653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [689]	valid_0's binary_logloss: 0.00360655
# [690]	valid_0's binary_logloss: 0.00360642
# [691]	valid_0's binary_logloss: 0.00360593
# [692]	valid_0's binary_logloss: 0.00360514
# [693]	valid_0's binary_logloss: 0.00360522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [694]	valid_0's binary_logloss: 0.00360478
# [695]	valid_0's binary_logloss: 0.00360614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [696]	valid_0's binary_logloss: 0.0036062
# [697]	valid_0's binary_logloss: 0.003606
# [698]	valid_0's binary_logloss: 0.00360618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [699]	valid_0's binary_logloss: 0.00360691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	valid_0's binary_logloss: 0.00360682
# [701]	valid_0's binary_logloss: 0.00360688
# [702]	valid_0's binary_logloss: 0.00360825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [703]	valid_0's binary_logloss: 0.00360928
# [704]	valid_0's binary_logloss: 0.00361065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [705]	valid_0's binary_logloss: 0.00361021
# [706]	valid_0's binary_logloss: 0.00361006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [707]	valid_0's binary_logloss: 0.00361064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [708]	valid_0's binary_logloss: 0.0036112
# [709]	valid_0's binary_logloss: 0.00361127
# [710]	valid_0's binary_logloss: 0.00361164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [711]	valid_0's binary_logloss: 0.0036124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [712]	valid_0's binary_logloss: 0.00361256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [713]	valid_0's binary_logloss: 0.00361264
# [714]	valid_0's binary_logloss: 0.00361403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [715]	valid_0's binary_logloss: 0.00361359
# [716]	valid_0's binary_logloss: 0.00361292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [717]	valid_0's binary_logloss: 0.00361395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [718]	valid_0's binary_logloss: 0.00361386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [719]	valid_0's binary_logloss: 0.00361445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [720]	valid_0's binary_logloss: 0.00361462
# [721]	valid_0's binary_logloss: 0.00361542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [722]	valid_0's binary_logloss: 0.00361525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [723]	valid_0's binary_logloss: 0.00361568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [724]	valid_0's binary_logloss: 0.0036156
# [725]	valid_0's binary_logloss: 0.00361582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [726]	valid_0's binary_logloss: 0.00361627
# [727]	valid_0's binary_logloss: 0.00361544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [728]	valid_0's binary_logloss: 0.00361602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [729]	valid_0's binary_logloss: 0.00361681
# [730]	valid_0's binary_logloss: 0.00361691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [731]	valid_0's binary_logloss: 0.00361709
# [732]	valid_0's binary_logloss: 0.0036162
# [733]	valid_0's binary_logloss: 0.0036164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [734]	valid_0's binary_logloss: 0.00361666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [735]	valid_0's binary_logloss: 0.00361668
# [736]	valid_0's binary_logloss: 0.00361742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [737]	valid_0's binary_logloss: 0.00361685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [738]	valid_0's binary_logloss: 0.00361791
# [739]	valid_0's binary_logloss: 0.0036195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [740]	valid_0's binary_logloss: 0.00361907
# [741]	valid_0's binary_logloss: 0.00361847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [742]	valid_0's binary_logloss: 0.00361837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [743]	valid_0's binary_logloss: 0.00361858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [744]	valid_0's binary_logloss: 0.00361902
# [745]	valid_0's binary_logloss: 0.00361965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [746]	valid_0's binary_logloss: 0.0036195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [747]	valid_0's binary_logloss: 0.00361977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [748]	valid_0's binary_logloss: 0.00361972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [749]	valid_0's binary_logloss: 0.00361916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	valid_0's binary_logloss: 0.00361961
# [751]	valid_0's binary_logloss: 0.00361888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [752]	valid_0's binary_logloss: 0.00361912
# [753]	valid_0's binary_logloss: 0.00361988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [754]	valid_0's binary_logloss: 0.00362048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [755]	valid_0's binary_logloss: 0.0036207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [756]	valid_0's binary_logloss: 0.00362015
# [757]	valid_0's binary_logloss: 0.00362095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [758]	valid_0's binary_logloss: 0.00362179
# [759]	valid_0's binary_logloss: 0.0036215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [760]	valid_0's binary_logloss: 0.00362136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [761]	valid_0's binary_logloss: 0.00362132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [762]	valid_0's binary_logloss: 0.00362179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [763]	valid_0's binary_logloss: 0.00362125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [764]	valid_0's binary_logloss: 0.0036213
# [765]	valid_0's binary_logloss: 0.0036223
# [766]	valid_0's binary_logloss: 0.00362193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [767]	valid_0's binary_logloss: 0.00362221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [768]	valid_0's binary_logloss: 0.00362246
# [769]	valid_0's binary_logloss: 0.00362161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [770]	valid_0's binary_logloss: 0.00362108
# [771]	valid_0's binary_logloss: 0.00362102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [772]	valid_0's binary_logloss: 0.00362125
# [773]	valid_0's binary_logloss: 0.00362226
# [774]	valid_0's binary_logloss: 0.00362172
# [775]	valid_0's binary_logloss: 0.00362196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [776]	valid_0's binary_logloss: 0.00362094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [777]	valid_0's binary_logloss: 0.00362181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [778]	valid_0's binary_logloss: 0.00362189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [779]	valid_0's binary_logloss: 0.00362178
# [780]	valid_0's binary_logloss: 0.00362279
# [781]	valid_0's binary_logloss: 0.0036225
# [782]	valid_0's binary_logloss: 0.00362306
# [783]	valid_0's binary_logloss: 0.00362468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [784]	valid_0's binary_logloss: 0.00362537
# [785]	valid_0's binary_logloss: 0.00362653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [786]	valid_0's binary_logloss: 0.00362701
# [787]	valid_0's binary_logloss: 0.00362619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [788]	valid_0's binary_logloss: 0.00362569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [789]	valid_0's binary_logloss: 0.00362596
# [790]	valid_0's binary_logloss: 0.00362686
# [791]	valid_0's binary_logloss: 0.00362598
# [792]	valid_0's binary_logloss: 0.00362624
# [793]	valid_0's binary_logloss: 0.00362679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [794]	valid_0's binary_logloss: 0.00362579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [795]	valid_0's binary_logloss: 0.00362569
# [796]	valid_0's binary_logloss: 0.00362671
# [797]	valid_0's binary_logloss: 0.00362761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [798]	valid_0's binary_logloss: 0.00362809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [799]	valid_0's binary_logloss: 0.00362761
# [800]	valid_0's binary_logloss: 0.00362835
# [801]	valid_0's binary_logloss: 0.00362756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [802]	valid_0's binary_logloss: 0.00362785
# [803]	valid_0's binary_logloss: 0.00362803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [804]	valid_0's binary_logloss: 0.00362832
# [805]	valid_0's binary_logloss: 0.00362754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [806]	valid_0's binary_logloss: 0.00362658
# [807]	valid_0's binary_logloss: 0.00362646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [808]	valid_0's binary_logloss: 0.00362675
# [809]	valid_0's binary_logloss: 0.00362716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [810]	valid_0's binary_logloss: 0.00362706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [811]	valid_0's binary_logloss: 0.00362736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [812]	valid_0's binary_logloss: 0.00362763
# [813]	valid_0's binary_logloss: 0.00362839
# [814]	valid_0's binary_logloss: 0.00362856
# [815]	valid_0's binary_logloss: 0.00362883
# [816]	valid_0's binary_logloss: 0.00362801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [817]	valid_0's binary_logloss: 0.00362831
# [818]	valid_0's binary_logloss: 0.00362899
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [819]	valid_0's binary_logloss: 0.00362929
# [820]	valid_0's binary_logloss: 0.00362919
# [821]	valid_0's binary_logloss: 0.00362838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [822]	valid_0's binary_logloss: 0.00362747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [823]	valid_0's binary_logloss: 0.00362768
# [824]	valid_0's binary_logloss: 0.00362798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [825]	valid_0's binary_logloss: 0.00362848
# [826]	valid_0's binary_logloss: 0.00362933
# [827]	valid_0's binary_logloss: 0.00362983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [828]	valid_0's binary_logloss: 0.00362898
# [829]	valid_0's binary_logloss: 0.0036293
# [830]	valid_0's binary_logloss: 0.00362928
# [831]	valid_0's binary_logloss: 0.0036292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [832]	valid_0's binary_logloss: 0.00362952
# [833]	valid_0's binary_logloss: 0.00362996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [834]	valid_0's binary_logloss: 0.00363046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [835]	valid_0's binary_logloss: 0.00363013
# [836]	valid_0's binary_logloss: 0.00363112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [837]	valid_0's binary_logloss: 0.00363025
# [838]	valid_0's binary_logloss: 0.00363054
# [839]	valid_0's binary_logloss: 0.00363022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [840]	valid_0's binary_logloss: 0.00363043
# [841]	valid_0's binary_logloss: 0.00363072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [842]	valid_0's binary_logloss: 0.00363095
# [843]	valid_0's binary_logloss: 0.00363126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [844]	valid_0's binary_logloss: 0.0036316
# [845]	valid_0's binary_logloss: 0.00363138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [846]	valid_0's binary_logloss: 0.00363057
# [847]	valid_0's binary_logloss: 0.00363109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [848]	valid_0's binary_logloss: 0.00363148
# [849]	valid_0's binary_logloss: 0.00363207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	valid_0's binary_logloss: 0.00363258
# [851]	valid_0's binary_logloss: 0.0036328
# [852]	valid_0's binary_logloss: 0.00363309
# [853]	valid_0's binary_logloss: 0.00363289
# [854]	valid_0's binary_logloss: 0.00363375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [855]	valid_0's binary_logloss: 0.00363297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [856]	valid_0's binary_logloss: 0.00363349
# [857]	valid_0's binary_logloss: 0.00363387
# [858]	valid_0's binary_logloss: 0.00363421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [859]	valid_0's binary_logloss: 0.00363446
# [860]	valid_0's binary_logloss: 0.00363496
# [861]	valid_0's binary_logloss: 0.00363497
# Early stopping, best iteration is:
# [661]	valid_0's binary_logloss: 0.0036019
# Training Log Loss:  0.0005292797023079082
# CV Log Loss:  0.0036019003071684464
# LightGBM Gradient Boosting Log Loss:  0.00280873207026739

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,'prediction']], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLightGBMGradientBoosting = preds.copy()

precision, recall, thresholds = \
    precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = \
    average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## **Test Set Evaluation**

# %%
predictionsTestSetLogisticRegression = \
    pd.DataFrame(data=[],index=y_test.index,columns=['prediction'])
predictionsTestSetLogisticRegression.loc[:,'prediction'] = \
    logReg.predict_proba(X_test)[:,1]
logLossTestSetLogisticRegression = \
    log_loss(y_test, predictionsTestSetLogisticRegression)
# Out:
# <ipython-input-47-19f79ed87de7>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   predictionsTestSetLogisticRegression.loc[:,'prediction'] = \

# %%
predictionsTestSetRandomForests = \
    pd.DataFrame(data=[],index=y_test.index,columns=['prediction'])
predictionsTestSetRandomForests.loc[:,'prediction'] = \
    RFC.predict_proba(X_test)[:,1]
logLossTestSetRandomForests = \
    log_loss(y_test, predictionsTestSetRandomForests)
# Out:
# <ipython-input-48-cc40bc6394de>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   predictionsTestSetRandomForests.loc[:,'prediction'] = \

# %%
predictionsTestSetLightGBMGradientBoosting = \
    pd.DataFrame(data=[],index=y_test.index,columns=['prediction'])
predictionsTestSetLightGBMGradientBoosting.loc[:,'prediction'] = \
    gbm.predict(X_test, num_iteration=gbm.best_iteration)
logLossTestSetLightGBMGradientBoosting = \
    log_loss(y_test, predictionsTestSetLightGBMGradientBoosting)
# Out:
# <ipython-input-49-5d54995e2e01>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   predictionsTestSetLightGBMGradientBoosting.loc[:,'prediction'] = \

# %%
print("Log Loss of Logistic Regression on Test Set: ", \
          logLossTestSetLogisticRegression)
print("Log Loss of Random Forests on Test Set: ", \
          logLossTestSetRandomForests)
print("Log Loss of LightGBM Gradient Boosting on Test Set: ", \
          logLossTestSetLightGBMGradientBoosting)
# Out:
# Log Loss of Logistic Regression on Test Set:  0.09701764485863619
# Log Loss of Random Forests on Test Set:  0.009380852421186473
# Log Loss of LightGBM Gradient Boosting on Test Set:  0.002523122137335972

# %%
precision, recall, thresholds = \
    precision_recall_curve(y_test,predictionsTestSetLogisticRegression)
average_precision = \
    average_precision_score(y_test,predictionsTestSetLogisticRegression)

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = roc_curve(y_test,predictionsTestSetLogisticRegression)
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
precision, recall, thresholds = \
    precision_recall_curve(y_test,predictionsTestSetRandomForests)
average_precision = \
    average_precision_score(y_test,predictionsTestSetRandomForests)

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = roc_curve(y_test,predictionsTestSetRandomForests)
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
precision, recall, thresholds = \
    precision_recall_curve(y_test,predictionsTestSetLightGBMGradientBoosting)
average_precision = \
    average_precision_score(y_test,predictionsTestSetLightGBMGradientBoosting)

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = \
    roc_curve(y_test,predictionsTestSetLightGBMGradientBoosting)
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## **Ensemble**

# %%
# Without XGBoost
predictionsBasedOnKFoldsFourModels = pd.DataFrame(data=[],index=y_train.index)
predictionsBasedOnKFoldsFourModels = predictionsBasedOnKFoldsFourModels.join(
    predictionsBasedOnKFoldsLogisticRegression['prediction'].astype(float), \
    how='left').join(predictionsBasedOnKFoldsRandomForests['prediction'] \
    .astype(float),how='left',rsuffix="2").join( \
    predictionsBasedOnKFoldsLightGBMGradientBoosting['prediction'].astype(float), \
    how='left',rsuffix="4")
predictionsBasedOnKFoldsFourModels.columns = \
    ['predsLR','predsRF','predsLightGBM']

# %%
X_trainWithPredictions = \
    X_train.merge(predictionsBasedOnKFoldsFourModels,
                  left_index=True,right_index=True)

# %%
params_lightGB = {
    'task': 'train',
    'application':'binary',
    'num_class':1,
    'boosting': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'metric_freq':50,
    'is_training_metric':False,
    'max_depth':4,
    'num_leaves': 31,
    'learning_rate': 0.01,
    'feature_fraction': 1.0,
    'bagging_fraction': 1.0,
    'bagging_freq': 0,
    'bagging_seed': 2018,
    'verbose': 0,
    'num_threads':16
}

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFoldsEnsemble = \
    pd.DataFrame(data=[],index=y_train.index,columns=['prediction'])

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)), \
                                          y_train.ravel()):
    X_train_fold, X_cv_fold = \
        X_trainWithPredictions.iloc[train_index,:], \
        X_trainWithPredictions.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]

    lgb_train = lgb.Dataset(X_train_fold, y_train_fold)
    lgb_eval = lgb.Dataset(X_cv_fold, y_cv_fold, reference=lgb_train)
    gbm = lgb.train(params_lightGB, lgb_train, num_boost_round=2000,
                   valid_sets=lgb_eval, early_stopping_rounds=200)

    loglossTraining = log_loss(y_train_fold, \
        gbm.predict(X_train_fold, num_iteration=gbm.best_iteration))
    trainingScores.append(loglossTraining)

    predictionsBasedOnKFoldsEnsemble.loc[X_cv_fold.index,'prediction'] = \
        gbm.predict(X_cv_fold, num_iteration=gbm.best_iteration)
    loglossCV = log_loss(y_cv_fold, \
        predictionsBasedOnKFoldsEnsemble.loc[X_cv_fold.index,'prediction'])
    cvScores.append(loglossCV)

    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)

loglossEnsemble = log_loss(y_train, \
        predictionsBasedOnKFoldsEnsemble.loc[:,'prediction'])
print('Ensemble Log Loss: ', loglossEnsemble)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.062540 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.00595349
# Training until validation scores don't improve for 200 rounds
# [2]	valid_0's binary_logloss: 0.00589641
# [3]	valid_0's binary_logloss: 0.00584372
# [4]	valid_0's binary_logloss: 0.00577896
# [5]	valid_0's binary_logloss: 0.00572908
# [6]	valid_0's binary_logloss: 0.00567224
# [7]	valid_0's binary_logloss: 0.00562463
# [8]	valid_0's binary_logloss: 0.00557833
# [9]	valid_0's binary_logloss: 0.00553206
# [10]	valid_0's binary_logloss: 0.00548635
# [11]	valid_0's binary_logloss: 0.00544392
# [12]	valid_0's binary_logloss: 0.00539729
# [13]	valid_0's binary_logloss: 0.00535769
# [14]	valid_0's binary_logloss: 0.00531471
# [15]	valid_0's binary_logloss: 0.00527544
# [16]	valid_0's binary_logloss: 0.0052386
# [17]	valid_0's binary_logloss: 0.00520012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.00516507
# [19]	valid_0's binary_logloss: 0.00513051
# [20]	valid_0's binary_logloss: 0.00509489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.00506032
# [22]	valid_0's binary_logloss: 0.00502594
# [23]	valid_0's binary_logloss: 0.00499142
# [24]	valid_0's binary_logloss: 0.00495803
# [25]	valid_0's binary_logloss: 0.00492503
# [26]	valid_0's binary_logloss: 0.00489353
# [27]	valid_0's binary_logloss: 0.004862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.00483216
# [29]	valid_0's binary_logloss: 0.00479924
# [30]	valid_0's binary_logloss: 0.00477113
# [31]	valid_0's binary_logloss: 0.00474426
# [32]	valid_0's binary_logloss: 0.00471801
# [33]	valid_0's binary_logloss: 0.00469224
# [34]	valid_0's binary_logloss: 0.00466654
# [35]	valid_0's binary_logloss: 0.00463662
# [36]	valid_0's binary_logloss: 0.00461029
# [37]	valid_0's binary_logloss: 0.00458331
# [38]	valid_0's binary_logloss: 0.00455822
# [39]	valid_0's binary_logloss: 0.0045331
# [40]	valid_0's binary_logloss: 0.00450633
# [41]	valid_0's binary_logloss: 0.00448132
# [42]	valid_0's binary_logloss: 0.00445748
# [43]	valid_0's binary_logloss: 0.00443543
# [44]	valid_0's binary_logloss: 0.00441188
# [45]	valid_0's binary_logloss: 0.00439092
# [46]	valid_0's binary_logloss: 0.00436848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.00434715
# [48]	valid_0's binary_logloss: 0.00432548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.00430495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.00428392
# [51]	valid_0's binary_logloss: 0.00426316
# [52]	valid_0's binary_logloss: 0.00424144
# [53]	valid_0's binary_logloss: 0.00422392
# [54]	valid_0's binary_logloss: 0.00420288
# [55]	valid_0's binary_logloss: 0.00418505
# [56]	valid_0's binary_logloss: 0.00416766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's binary_logloss: 0.00414892
# [58]	valid_0's binary_logloss: 0.00413133
# [59]	valid_0's binary_logloss: 0.0041144
# [60]	valid_0's binary_logloss: 0.00409762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's binary_logloss: 0.00407941
# [62]	valid_0's binary_logloss: 0.00406264
# [63]	valid_0's binary_logloss: 0.00404492
# [64]	valid_0's binary_logloss: 0.00402802
# [65]	valid_0's binary_logloss: 0.00401206
# [66]	valid_0's binary_logloss: 0.00399519
# [67]	valid_0's binary_logloss: 0.00397963
# [68]	valid_0's binary_logloss: 0.00396292
# [69]	valid_0's binary_logloss: 0.00394725
# [70]	valid_0's binary_logloss: 0.00393215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.00391652
# [72]	valid_0's binary_logloss: 0.00390153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.00388693
# [74]	valid_0's binary_logloss: 0.00387309
# [75]	valid_0's binary_logloss: 0.00385882
# [76]	valid_0's binary_logloss: 0.00384322
# [77]	valid_0's binary_logloss: 0.00382961
# [78]	valid_0's binary_logloss: 0.00381512
# [79]	valid_0's binary_logloss: 0.00379914
# [80]	valid_0's binary_logloss: 0.00378629
# [81]	valid_0's binary_logloss: 0.00377453
# [82]	valid_0's binary_logloss: 0.00376087
# [83]	valid_0's binary_logloss: 0.00374573
# [84]	valid_0's binary_logloss: 0.00373319
# [85]	valid_0's binary_logloss: 0.00372055
# [86]	valid_0's binary_logloss: 0.00370942
# [87]	valid_0's binary_logloss: 0.00369751
# [88]	valid_0's binary_logloss: 0.00368555
# [89]	valid_0's binary_logloss: 0.00367502
# [90]	valid_0's binary_logloss: 0.0036643
# [91]	valid_0's binary_logloss: 0.0036532
# [92]	valid_0's binary_logloss: 0.00364104
# [93]	valid_0's binary_logloss: 0.00362875
# [94]	valid_0's binary_logloss: 0.00361877
# [95]	valid_0's binary_logloss: 0.00360753
# [96]	valid_0's binary_logloss: 0.00359583
# [97]	valid_0's binary_logloss: 0.00358375
# [98]	valid_0's binary_logloss: 0.00357327
# [99]	valid_0's binary_logloss: 0.00356243
# [100]	valid_0's binary_logloss: 0.00355368
# [101]	valid_0's binary_logloss: 0.00354354
# [102]	valid_0's binary_logloss: 0.00353253
# [103]	valid_0's binary_logloss: 0.00352185
# [104]	valid_0's binary_logloss: 0.00351125
# [105]	valid_0's binary_logloss: 0.00350061
# [106]	valid_0's binary_logloss: 0.00349039
# [107]	valid_0's binary_logloss: 0.0034803
# [108]	valid_0's binary_logloss: 0.00347103
# [109]	valid_0's binary_logloss: 0.00346199
# [110]	valid_0's binary_logloss: 0.0034517
# [111]	valid_0's binary_logloss: 0.00344203
# [112]	valid_0's binary_logloss: 0.0034325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's binary_logloss: 0.00342266
# [114]	valid_0's binary_logloss: 0.00341107
# [115]	valid_0's binary_logloss: 0.00340425
# [116]	valid_0's binary_logloss: 0.00339327
# [117]	valid_0's binary_logloss: 0.00338627
# [118]	valid_0's binary_logloss: 0.0033786
# [119]	valid_0's binary_logloss: 0.00337192
# [120]	valid_0's binary_logloss: 0.00336199
# [121]	valid_0's binary_logloss: 0.00335474
# [122]	valid_0's binary_logloss: 0.0033444
# [123]	valid_0's binary_logloss: 0.00333856
# [124]	valid_0's binary_logloss: 0.00332814
# [125]	valid_0's binary_logloss: 0.00332106
# [126]	valid_0's binary_logloss: 0.00331411
# [127]	valid_0's binary_logloss: 0.00330629
# [128]	valid_0's binary_logloss: 0.00329811
# [129]	valid_0's binary_logloss: 0.00329049
# [130]	valid_0's binary_logloss: 0.0032852
# [131]	valid_0's binary_logloss: 0.00327853
# [132]	valid_0's binary_logloss: 0.00327365
# [133]	valid_0's binary_logloss: 0.0032677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's binary_logloss: 0.00325908
# [135]	valid_0's binary_logloss: 0.00325187
# [136]	valid_0's binary_logloss: 0.00324569
# [137]	valid_0's binary_logloss: 0.00324076
# [138]	valid_0's binary_logloss: 0.00323413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's binary_logloss: 0.00322648
# [140]	valid_0's binary_logloss: 0.00322135
# [141]	valid_0's binary_logloss: 0.00321587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's binary_logloss: 0.00320844
# [143]	valid_0's binary_logloss: 0.00320331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's binary_logloss: 0.00319718
# [145]	valid_0's binary_logloss: 0.00318974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's binary_logloss: 0.00318256
# [147]	valid_0's binary_logloss: 0.00317667
# [148]	valid_0's binary_logloss: 0.00317086
# [149]	valid_0's binary_logloss: 0.00316511
# [150]	valid_0's binary_logloss: 0.00315943
# [151]	valid_0's binary_logloss: 0.00315449
# [152]	valid_0's binary_logloss: 0.00314899
# [153]	valid_0's binary_logloss: 0.00314419
# [154]	valid_0's binary_logloss: 0.00313883
# [155]	valid_0's binary_logloss: 0.00313364
# [156]	valid_0's binary_logloss: 0.00312899
# [157]	valid_0's binary_logloss: 0.0031239
# [158]	valid_0's binary_logloss: 0.00311883
# [159]	valid_0's binary_logloss: 0.00311276
# [160]	valid_0's binary_logloss: 0.00310656
# [161]	valid_0's binary_logloss: 0.00310068
# [162]	valid_0's binary_logloss: 0.00309475
# [163]	valid_0's binary_logloss: 0.00309054
# [164]	valid_0's binary_logloss: 0.00308506
# [165]	valid_0's binary_logloss: 0.00307906
# [166]	valid_0's binary_logloss: 0.00307437
# [167]	valid_0's binary_logloss: 0.00306881
# [168]	valid_0's binary_logloss: 0.00306317
# [169]	valid_0's binary_logloss: 0.00305872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's binary_logloss: 0.00305478
# [171]	valid_0's binary_logloss: 0.00305073
# [172]	valid_0's binary_logloss: 0.00304562
# [173]	valid_0's binary_logloss: 0.00304181
# [174]	valid_0's binary_logloss: 0.00303658
# [175]	valid_0's binary_logloss: 0.00303156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's binary_logloss: 0.00302803
# [177]	valid_0's binary_logloss: 0.00302338
# [178]	valid_0's binary_logloss: 0.00301899
# [179]	valid_0's binary_logloss: 0.00301564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's binary_logloss: 0.00301221
# [181]	valid_0's binary_logloss: 0.00300852
# [182]	valid_0's binary_logloss: 0.0030035
# [183]	valid_0's binary_logloss: 0.00299899
# [184]	valid_0's binary_logloss: 0.00299479
# [185]	valid_0's binary_logloss: 0.00299125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's binary_logloss: 0.0029872
# [187]	valid_0's binary_logloss: 0.00298326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's binary_logloss: 0.00297981
# [189]	valid_0's binary_logloss: 0.00297336
# [190]	valid_0's binary_logloss: 0.00296926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.00296532
# [192]	valid_0's binary_logloss: 0.00296233
# [193]	valid_0's binary_logloss: 0.00295727
# [194]	valid_0's binary_logloss: 0.00295356
# [195]	valid_0's binary_logloss: 0.0029474
# [196]	valid_0's binary_logloss: 0.00294298
# [197]	valid_0's binary_logloss: 0.00294021
# [198]	valid_0's binary_logloss: 0.00293408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's binary_logloss: 0.00293037
# [200]	valid_0's binary_logloss: 0.00292578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.00292324
# [202]	valid_0's binary_logloss: 0.00291876
# [203]	valid_0's binary_logloss: 0.00291625
# [204]	valid_0's binary_logloss: 0.00291322
# [205]	valid_0's binary_logloss: 0.00290956
# [206]	valid_0's binary_logloss: 0.00290697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.0029034
# [208]	valid_0's binary_logloss: 0.00290056
# [209]	valid_0's binary_logloss: 0.00289695
# [210]	valid_0's binary_logloss: 0.00289452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's binary_logloss: 0.00289129
# [212]	valid_0's binary_logloss: 0.00288884
# [213]	valid_0's binary_logloss: 0.00288651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's binary_logloss: 0.00288316
# [215]	valid_0's binary_logloss: 0.00288079
# [216]	valid_0's binary_logloss: 0.00287801
# [217]	valid_0's binary_logloss: 0.002875
# [218]	valid_0's binary_logloss: 0.0028728
# [219]	valid_0's binary_logloss: 0.00287067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's binary_logloss: 0.00286772
# [221]	valid_0's binary_logloss: 0.00286541
# [222]	valid_0's binary_logloss: 0.00286292
# [223]	valid_0's binary_logloss: 0.00286089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's binary_logloss: 0.00285838
# [225]	valid_0's binary_logloss: 0.00285687
# [226]	valid_0's binary_logloss: 0.00285571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's binary_logloss: 0.00285235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's binary_logloss: 0.00284958
# [229]	valid_0's binary_logloss: 0.00284773
# [230]	valid_0's binary_logloss: 0.00284609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's binary_logloss: 0.00284333
# [232]	valid_0's binary_logloss: 0.00284158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's binary_logloss: 0.00283924
# [234]	valid_0's binary_logloss: 0.00283821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's binary_logloss: 0.00283521
# [236]	valid_0's binary_logloss: 0.00283359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.00283117
# [238]	valid_0's binary_logloss: 0.00282955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.00282708
# [240]	valid_0's binary_logloss: 0.00282593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's binary_logloss: 0.00282311
# [242]	valid_0's binary_logloss: 0.00282204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.00281923
# [244]	valid_0's binary_logloss: 0.00281778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's binary_logloss: 0.00281584
# [246]	valid_0's binary_logloss: 0.00281397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's binary_logloss: 0.00281195
# [248]	valid_0's binary_logloss: 0.00281099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.00280931
# [250]	valid_0's binary_logloss: 0.00280804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's binary_logloss: 0.00280632
# [252]	valid_0's binary_logloss: 0.0028055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.00280291
# [254]	valid_0's binary_logloss: 0.00280128
# [255]	valid_0's binary_logloss: 0.00280076
# [256]	valid_0's binary_logloss: 0.00279957
# [257]	valid_0's binary_logloss: 0.00279925
# [258]	valid_0's binary_logloss: 0.00279829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.00279653
# [260]	valid_0's binary_logloss: 0.00279532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.00279348
# [262]	valid_0's binary_logloss: 0.00279241
# [263]	valid_0's binary_logloss: 0.00279131
# [264]	valid_0's binary_logloss: 0.00279008
# [265]	valid_0's binary_logloss: 0.00278893
# [266]	valid_0's binary_logloss: 0.00278801
# [267]	valid_0's binary_logloss: 0.00278725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.00278585
# [269]	valid_0's binary_logloss: 0.00278509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.00278147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's binary_logloss: 0.00277947
# [272]	valid_0's binary_logloss: 0.00277869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.00277649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's binary_logloss: 0.0027746
# [275]	valid_0's binary_logloss: 0.00277428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's binary_logloss: 0.00277212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's binary_logloss: 0.00277049
# [278]	valid_0's binary_logloss: 0.00277041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's binary_logloss: 0.00276855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.00276711
# [281]	valid_0's binary_logloss: 0.00276674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.0027648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's binary_logloss: 0.00276233
# [284]	valid_0's binary_logloss: 0.00276225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.00276081
# [286]	valid_0's binary_logloss: 0.00276004
# [287]	valid_0's binary_logloss: 0.00275879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's binary_logloss: 0.002757
# [289]	valid_0's binary_logloss: 0.00275579
# [290]	valid_0's binary_logloss: 0.00275421
# [291]	valid_0's binary_logloss: 0.00275234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.00275079
# [293]	valid_0's binary_logloss: 0.00274931
# [294]	valid_0's binary_logloss: 0.00274819
# [295]	valid_0's binary_logloss: 0.00274673
# [296]	valid_0's binary_logloss: 0.00274586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.00274473
# [298]	valid_0's binary_logloss: 0.0027439
# [299]	valid_0's binary_logloss: 0.00274246
# [300]	valid_0's binary_logloss: 0.00274119
# [301]	valid_0's binary_logloss: 0.0027405
# [302]	valid_0's binary_logloss: 0.00274008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's binary_logloss: 0.00273847
# [304]	valid_0's binary_logloss: 0.00273667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's binary_logloss: 0.00273565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's binary_logloss: 0.00273418
# [307]	valid_0's binary_logloss: 0.00273424
# [308]	valid_0's binary_logloss: 0.00273305
# [309]	valid_0's binary_logloss: 0.00273338
# [310]	valid_0's binary_logloss: 0.00273223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's binary_logloss: 0.00273129
# [312]	valid_0's binary_logloss: 0.00272995
# [313]	valid_0's binary_logloss: 0.00272994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.00272913
# [315]	valid_0's binary_logloss: 0.00272831
# [316]	valid_0's binary_logloss: 0.00272747
# [317]	valid_0's binary_logloss: 0.00272668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.00272665
# [319]	valid_0's binary_logloss: 0.00272594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.0027252
# [321]	valid_0's binary_logloss: 0.00272505
# [322]	valid_0's binary_logloss: 0.00272472
# [323]	valid_0's binary_logloss: 0.00272393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.00272391
# [325]	valid_0's binary_logloss: 0.00272241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.00272163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.00272164
# [328]	valid_0's binary_logloss: 0.00272008
# [329]	valid_0's binary_logloss: 0.00272007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.00271909
# [331]	valid_0's binary_logloss: 0.00271881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.00271862
# [333]	valid_0's binary_logloss: 0.00271636
# [334]	valid_0's binary_logloss: 0.00271534
# [335]	valid_0's binary_logloss: 0.00271479
# [336]	valid_0's binary_logloss: 0.00271501
# [337]	valid_0's binary_logloss: 0.00271459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.00271474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.0027142
# [340]	valid_0's binary_logloss: 0.00271406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's binary_logloss: 0.00271322
# [342]	valid_0's binary_logloss: 0.00271105
# [343]	valid_0's binary_logloss: 0.00270975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's binary_logloss: 0.0027096
# [345]	valid_0's binary_logloss: 0.00271001
# [346]	valid_0's binary_logloss: 0.00270955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.0027095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.00270936
# [349]	valid_0's binary_logloss: 0.00270823
# [350]	valid_0's binary_logloss: 0.00270802
# [351]	valid_0's binary_logloss: 0.00270752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.00270744
# [353]	valid_0's binary_logloss: 0.00270601
# [354]	valid_0's binary_logloss: 0.00270475
# [355]	valid_0's binary_logloss: 0.00270518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's binary_logloss: 0.00270472
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.00270466
# [358]	valid_0's binary_logloss: 0.0027038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.00270372
# [360]	valid_0's binary_logloss: 0.00270308
# [361]	valid_0's binary_logloss: 0.0027028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.00270338
# [363]	valid_0's binary_logloss: 0.00270313
# [364]	valid_0's binary_logloss: 0.00270232
# [365]	valid_0's binary_logloss: 0.00270136
# [366]	valid_0's binary_logloss: 0.00270097
# [367]	valid_0's binary_logloss: 0.00270061
# [368]	valid_0's binary_logloss: 0.0026995
# [369]	valid_0's binary_logloss: 0.00269942
# [370]	valid_0's binary_logloss: 0.00269989
# [371]	valid_0's binary_logloss: 0.00269882
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's binary_logloss: 0.00269809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.00269749
# [374]	valid_0's binary_logloss: 0.00269672
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.00269599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.00269541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.00269431
# [378]	valid_0's binary_logloss: 0.00269419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's binary_logloss: 0.00269411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.00269342
# [381]	valid_0's binary_logloss: 0.0026933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.00269323
# [383]	valid_0's binary_logloss: 0.00269346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's binary_logloss: 0.00269278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.00269171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.00269165
# [387]	valid_0's binary_logloss: 0.00269159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.00269092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.00269087
# [390]	valid_0's binary_logloss: 0.00268918
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.00268913
# [392]	valid_0's binary_logloss: 0.00268942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.00268883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.00268879
# [395]	valid_0's binary_logloss: 0.00268779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.00268722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.00268719
# [398]	valid_0's binary_logloss: 0.00268718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.00268597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.00268541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's binary_logloss: 0.00268445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's binary_logloss: 0.00268399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's binary_logloss: 0.00268398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's binary_logloss: 0.00268278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's binary_logloss: 0.0026826
# [406]	valid_0's binary_logloss: 0.00268258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's binary_logloss: 0.00268165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's binary_logloss: 0.00268047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's binary_logloss: 0.00268095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's binary_logloss: 0.00268095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's binary_logloss: 0.00268043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's binary_logloss: 0.00267904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's binary_logloss: 0.00267865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's binary_logloss: 0.00267835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's binary_logloss: 0.00267785
# [416]	valid_0's binary_logloss: 0.00267787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's binary_logloss: 0.00267651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's binary_logloss: 0.00267614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's binary_logloss: 0.00267559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's binary_logloss: 0.00267438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's binary_logloss: 0.00267391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's binary_logloss: 0.00267415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's binary_logloss: 0.00267417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's binary_logloss: 0.00267361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's binary_logloss: 0.00267263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's binary_logloss: 0.00267198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's binary_logloss: 0.00267069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's binary_logloss: 0.0026703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's binary_logloss: 0.00266994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's binary_logloss: 0.00266981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's binary_logloss: 0.00266996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [432]	valid_0's binary_logloss: 0.00267046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's binary_logloss: 0.00266993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's binary_logloss: 0.00266959
# [435]	valid_0's binary_logloss: 0.00267035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	valid_0's binary_logloss: 0.0026704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	valid_0's binary_logloss: 0.00266989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's binary_logloss: 0.00266956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's binary_logloss: 0.00266923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's binary_logloss: 0.0026694
# [441]	valid_0's binary_logloss: 0.00266827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	valid_0's binary_logloss: 0.00266697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	valid_0's binary_logloss: 0.00266645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's binary_logloss: 0.00266674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [445]	valid_0's binary_logloss: 0.00266681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's binary_logloss: 0.00266693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's binary_logloss: 0.00266638
# [448]	valid_0's binary_logloss: 0.00266638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's binary_logloss: 0.00266587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	valid_0's binary_logloss: 0.00266545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	valid_0's binary_logloss: 0.00266515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's binary_logloss: 0.00266534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's binary_logloss: 0.00266549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	valid_0's binary_logloss: 0.00266521
# [455]	valid_0's binary_logloss: 0.00266509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [456]	valid_0's binary_logloss: 0.00266459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [457]	valid_0's binary_logloss: 0.00266433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's binary_logloss: 0.0026645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459]	valid_0's binary_logloss: 0.00266423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	valid_0's binary_logloss: 0.00266397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [461]	valid_0's binary_logloss: 0.00266348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	valid_0's binary_logloss: 0.00266366
# [463]	valid_0's binary_logloss: 0.00266325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [464]	valid_0's binary_logloss: 0.00266299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [465]	valid_0's binary_logloss: 0.00266275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [466]	valid_0's binary_logloss: 0.0026629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [467]	valid_0's binary_logloss: 0.00266261
# [468]	valid_0's binary_logloss: 0.00266326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [469]	valid_0's binary_logloss: 0.00266338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	valid_0's binary_logloss: 0.00266304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [471]	valid_0's binary_logloss: 0.00266316
# [472]	valid_0's binary_logloss: 0.00266383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [473]	valid_0's binary_logloss: 0.00266349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [474]	valid_0's binary_logloss: 0.00266363
# [475]	valid_0's binary_logloss: 0.00266423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [476]	valid_0's binary_logloss: 0.00266471
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	valid_0's binary_logloss: 0.0026644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [478]	valid_0's binary_logloss: 0.00266448
# [479]	valid_0's binary_logloss: 0.00266551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	valid_0's binary_logloss: 0.00266601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [481]	valid_0's binary_logloss: 0.00266555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	valid_0's binary_logloss: 0.00266569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [483]	valid_0's binary_logloss: 0.00266541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [484]	valid_0's binary_logloss: 0.00266591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [485]	valid_0's binary_logloss: 0.00266561
# [486]	valid_0's binary_logloss: 0.00266595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [487]	valid_0's binary_logloss: 0.00266635
# [488]	valid_0's binary_logloss: 0.0026667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's binary_logloss: 0.00266642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	valid_0's binary_logloss: 0.00266703
# [491]	valid_0's binary_logloss: 0.00266739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [492]	valid_0's binary_logloss: 0.00266801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	valid_0's binary_logloss: 0.00266756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [494]	valid_0's binary_logloss: 0.00266797
# [495]	valid_0's binary_logloss: 0.00266868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [496]	valid_0's binary_logloss: 0.0026685
# [497]	valid_0's binary_logloss: 0.00266789
# [498]	valid_0's binary_logloss: 0.00266827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	valid_0's binary_logloss: 0.00266889
# [500]	valid_0's binary_logloss: 0.0026683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	valid_0's binary_logloss: 0.00266804
# [502]	valid_0's binary_logloss: 0.00266844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	valid_0's binary_logloss: 0.00266906
# [504]	valid_0's binary_logloss: 0.0026685
# [505]	valid_0's binary_logloss: 0.0026689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	valid_0's binary_logloss: 0.00266875
# [507]	valid_0's binary_logloss: 0.00266821
# [508]	valid_0's binary_logloss: 0.00266864
# [509]	valid_0's binary_logloss: 0.00266812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	valid_0's binary_logloss: 0.00266834
# [511]	valid_0's binary_logloss: 0.00266782
# [512]	valid_0's binary_logloss: 0.00266844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [513]	valid_0's binary_logloss: 0.00266907
# [514]	valid_0's binary_logloss: 0.00266862
# [515]	valid_0's binary_logloss: 0.00266921
# [516]	valid_0's binary_logloss: 0.00266968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [517]	valid_0's binary_logloss: 0.00266987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [518]	valid_0's binary_logloss: 0.00266968
# [519]	valid_0's binary_logloss: 0.00266916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	valid_0's binary_logloss: 0.00266979
# [521]	valid_0's binary_logloss: 0.00266957
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [522]	valid_0's binary_logloss: 0.00266943
# [523]	valid_0's binary_logloss: 0.0026691
# [524]	valid_0's binary_logloss: 0.00266955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [525]	valid_0's binary_logloss: 0.00266937
# [526]	valid_0's binary_logloss: 0.00266915
# [527]	valid_0's binary_logloss: 0.00266957
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	valid_0's binary_logloss: 0.00266939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [529]	valid_0's binary_logloss: 0.00266897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [530]	valid_0's binary_logloss: 0.0026696
# [531]	valid_0's binary_logloss: 0.00266939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	valid_0's binary_logloss: 0.00266922
# [533]	valid_0's binary_logloss: 0.00267019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [534]	valid_0's binary_logloss: 0.00266978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [535]	valid_0's binary_logloss: 0.00266961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [536]	valid_0's binary_logloss: 0.00267024
# [537]	valid_0's binary_logloss: 0.00267046
# [538]	valid_0's binary_logloss: 0.00267041
# [539]	valid_0's binary_logloss: 0.00267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [540]	valid_0's binary_logloss: 0.00266984
# [541]	valid_0's binary_logloss: 0.00267033
# [542]	valid_0's binary_logloss: 0.00267067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543]	valid_0's binary_logloss: 0.00267088
# [544]	valid_0's binary_logloss: 0.00267073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [545]	valid_0's binary_logloss: 0.00267136
# [546]	valid_0's binary_logloss: 0.00267177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	valid_0's binary_logloss: 0.00267161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [548]	valid_0's binary_logloss: 0.00267123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [549]	valid_0's binary_logloss: 0.00267092
# [550]	valid_0's binary_logloss: 0.00267143
# [551]	valid_0's binary_logloss: 0.00267114
# [552]	valid_0's binary_logloss: 0.00267113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [553]	valid_0's binary_logloss: 0.00267097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [554]	valid_0's binary_logloss: 0.0026707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [555]	valid_0's binary_logloss: 0.00267046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [556]	valid_0's binary_logloss: 0.00267069
# [557]	valid_0's binary_logloss: 0.00267042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	valid_0's binary_logloss: 0.00267012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [559]	valid_0's binary_logloss: 0.00267008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [560]	valid_0's binary_logloss: 0.00267069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [561]	valid_0's binary_logloss: 0.00267053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	valid_0's binary_logloss: 0.00267056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	valid_0's binary_logloss: 0.00267119
# [564]	valid_0's binary_logloss: 0.00267125
# [565]	valid_0's binary_logloss: 0.00267178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [566]	valid_0's binary_logloss: 0.00267156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [567]	valid_0's binary_logloss: 0.00267142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [568]	valid_0's binary_logloss: 0.00267153
# [569]	valid_0's binary_logloss: 0.00267198
# [570]	valid_0's binary_logloss: 0.0026728
# [571]	valid_0's binary_logloss: 0.00267324
# [572]	valid_0's binary_logloss: 0.0026737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [573]	valid_0's binary_logloss: 0.00267358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [574]	valid_0's binary_logloss: 0.00267323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [575]	valid_0's binary_logloss: 0.00267295
# [576]	valid_0's binary_logloss: 0.00267211
# [577]	valid_0's binary_logloss: 0.00267265
# [578]	valid_0's binary_logloss: 0.00267269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [579]	valid_0's binary_logloss: 0.00267295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [580]	valid_0's binary_logloss: 0.00267286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [581]	valid_0's binary_logloss: 0.00267273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [582]	valid_0's binary_logloss: 0.00267273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [583]	valid_0's binary_logloss: 0.00267287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [584]	valid_0's binary_logloss: 0.00267262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [585]	valid_0's binary_logloss: 0.00267249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	valid_0's binary_logloss: 0.00267289
# [587]	valid_0's binary_logloss: 0.00267259
# [588]	valid_0's binary_logloss: 0.00267318
# [589]	valid_0's binary_logloss: 0.00267326
# [590]	valid_0's binary_logloss: 0.00267298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [591]	valid_0's binary_logloss: 0.00267349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [592]	valid_0's binary_logloss: 0.00267324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [593]	valid_0's binary_logloss: 0.00267293
# [594]	valid_0's binary_logloss: 0.00267338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [595]	valid_0's binary_logloss: 0.00267325
# [596]	valid_0's binary_logloss: 0.00267278
# [597]	valid_0's binary_logloss: 0.00267247
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [598]	valid_0's binary_logloss: 0.00267311
# [599]	valid_0's binary_logloss: 0.00267293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	valid_0's binary_logloss: 0.00267294
# [601]	valid_0's binary_logloss: 0.00267277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [602]	valid_0's binary_logloss: 0.00267254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [603]	valid_0's binary_logloss: 0.00267294
# [604]	valid_0's binary_logloss: 0.00267341
# [605]	valid_0's binary_logloss: 0.00267324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [606]	valid_0's binary_logloss: 0.00267331
# [607]	valid_0's binary_logloss: 0.00267304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [608]	valid_0's binary_logloss: 0.00267358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [609]	valid_0's binary_logloss: 0.00267397
# [610]	valid_0's binary_logloss: 0.00267323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	valid_0's binary_logloss: 0.00267325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [612]	valid_0's binary_logloss: 0.00267312
# [613]	valid_0's binary_logloss: 0.00267296
# [614]	valid_0's binary_logloss: 0.00267253
# [615]	valid_0's binary_logloss: 0.00267186
# [616]	valid_0's binary_logloss: 0.00267249
# [617]	valid_0's binary_logloss: 0.00267294
# [618]	valid_0's binary_logloss: 0.00267191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [619]	valid_0's binary_logloss: 0.00267188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [620]	valid_0's binary_logloss: 0.00267176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [621]	valid_0's binary_logloss: 0.00267184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	valid_0's binary_logloss: 0.00267187
# [623]	valid_0's binary_logloss: 0.00267087
# [624]	valid_0's binary_logloss: 0.00267087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [625]	valid_0's binary_logloss: 0.00267198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [626]	valid_0's binary_logloss: 0.00267238
# [627]	valid_0's binary_logloss: 0.00267224
# [628]	valid_0's binary_logloss: 0.00267134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [629]	valid_0's binary_logloss: 0.00267141
# [630]	valid_0's binary_logloss: 0.00267129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	valid_0's binary_logloss: 0.00267137
# [632]	valid_0's binary_logloss: 0.0026713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [633]	valid_0's binary_logloss: 0.00267116
# [634]	valid_0's binary_logloss: 0.00267171
# [635]	valid_0's binary_logloss: 0.00267162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [636]	valid_0's binary_logloss: 0.0026715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [637]	valid_0's binary_logloss: 0.00267149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [638]	valid_0's binary_logloss: 0.00267261
# [639]	valid_0's binary_logloss: 0.00267167
# [640]	valid_0's binary_logloss: 0.00267184
# [641]	valid_0's binary_logloss: 0.00267096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642]	valid_0's binary_logloss: 0.00267125
# [643]	valid_0's binary_logloss: 0.00267172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [644]	valid_0's binary_logloss: 0.00267181
# [645]	valid_0's binary_logloss: 0.00267197
# ...
# [319]	valid_0's binary_logloss: 0.0033893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.00338929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's binary_logloss: 0.00338883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's binary_logloss: 0.00338836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's binary_logloss: 0.00338838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.00338854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.00338835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.00338783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.00338805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's binary_logloss: 0.00338812
# [329]	valid_0's binary_logloss: 0.00338953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.00338943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.00338971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.00338994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.0033898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's binary_logloss: 0.00338992
# [335]	valid_0's binary_logloss: 0.00339138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's binary_logloss: 0.00339157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's binary_logloss: 0.0033916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.00339317
# [339]	valid_0's binary_logloss: 0.0033933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's binary_logloss: 0.00339366
# [341]	valid_0's binary_logloss: 0.00339485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.00339496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.00339521
# [344]	valid_0's binary_logloss: 0.00339565
# [345]	valid_0's binary_logloss: 0.00339607
# [346]	valid_0's binary_logloss: 0.00339716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.00339756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.00339797
# [349]	valid_0's binary_logloss: 0.00339946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's binary_logloss: 0.00339974
# [351]	valid_0's binary_logloss: 0.00339987
# [352]	valid_0's binary_logloss: 0.00340012
# [353]	valid_0's binary_logloss: 0.00340196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's binary_logloss: 0.00340241
# [355]	valid_0's binary_logloss: 0.00340265
# [356]	valid_0's binary_logloss: 0.00340422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.00340469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's binary_logloss: 0.00340483
# [359]	valid_0's binary_logloss: 0.00340628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.00340667
# [361]	valid_0's binary_logloss: 0.00340808
# [362]	valid_0's binary_logloss: 0.00340827
# [363]	valid_0's binary_logloss: 0.00340869
# [364]	valid_0's binary_logloss: 0.00340975
# [365]	valid_0's binary_logloss: 0.00340999
# [366]	valid_0's binary_logloss: 0.0034105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.00341102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.00341154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.00341198
# [370]	valid_0's binary_logloss: 0.00341225
# [371]	valid_0's binary_logloss: 0.00341286
# [372]	valid_0's binary_logloss: 0.00341319
# [373]	valid_0's binary_logloss: 0.00341399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's binary_logloss: 0.00341455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.00341497
# [376]	valid_0's binary_logloss: 0.00341499
# [377]	valid_0's binary_logloss: 0.00341537
# [378]	valid_0's binary_logloss: 0.00341551
# [379]	valid_0's binary_logloss: 0.00341572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.0034162
# [381]	valid_0's binary_logloss: 0.00341622
# [382]	valid_0's binary_logloss: 0.00341681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.00341744
# [384]	valid_0's binary_logloss: 0.00341875
# [385]	valid_0's binary_logloss: 0.00341892
# [386]	valid_0's binary_logloss: 0.0034196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's binary_logloss: 0.00342021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.00342069
# [389]	valid_0's binary_logloss: 0.00342069
# [390]	valid_0's binary_logloss: 0.00342185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.00342237
# [392]	valid_0's binary_logloss: 0.00342241
# [393]	valid_0's binary_logloss: 0.0034236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.00342425
# [395]	valid_0's binary_logloss: 0.00342448
# [396]	valid_0's binary_logloss: 0.00342589
# [397]	valid_0's binary_logloss: 0.00342643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.00342712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.00342768
# [400]	valid_0's binary_logloss: 0.00342853
# [401]	valid_0's binary_logloss: 0.00343
# [402]	valid_0's binary_logloss: 0.0034286
# [403]	valid_0's binary_logloss: 0.00342977
# [404]	valid_0's binary_logloss: 0.00343012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's binary_logloss: 0.00343069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's binary_logloss: 0.00343137
# [407]	valid_0's binary_logloss: 0.00343235
# [408]	valid_0's binary_logloss: 0.00343158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's binary_logloss: 0.00343228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's binary_logloss: 0.00343287
# [411]	valid_0's binary_logloss: 0.00343244
# [412]	valid_0's binary_logloss: 0.00343202
# [413]	valid_0's binary_logloss: 0.00343281
# [414]	valid_0's binary_logloss: 0.00343304
# [415]	valid_0's binary_logloss: 0.00343271
# [416]	valid_0's binary_logloss: 0.00343257
# [417]	valid_0's binary_logloss: 0.0034324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's binary_logloss: 0.0034331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's binary_logloss: 0.00343371
# [420]	valid_0's binary_logloss: 0.00343351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's binary_logloss: 0.00343442
# [422]	valid_0's binary_logloss: 0.00343514
# [423]	valid_0's binary_logloss: 0.00343548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's binary_logloss: 0.00343641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's binary_logloss: 0.00343734
# [426]	valid_0's binary_logloss: 0.00343693
# [427]	valid_0's binary_logloss: 0.00343781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's binary_logloss: 0.00343875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's binary_logloss: 0.00343939
# [430]	valid_0's binary_logloss: 0.00344024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's binary_logloss: 0.00344095
# [432]	valid_0's binary_logloss: 0.00344034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's binary_logloss: 0.00343988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's binary_logloss: 0.00344047
# [435]	valid_0's binary_logloss: 0.0034418
# [436]	valid_0's binary_logloss: 0.00344161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	valid_0's binary_logloss: 0.00344257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's binary_logloss: 0.0034431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's binary_logloss: 0.00344384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's binary_logloss: 0.00344302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's binary_logloss: 0.00344366
# [442]	valid_0's binary_logloss: 0.00344459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	valid_0's binary_logloss: 0.00344526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's binary_logloss: 0.00344495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [445]	valid_0's binary_logloss: 0.00344524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's binary_logloss: 0.00344585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's binary_logloss: 0.0034466
# [448]	valid_0's binary_logloss: 0.00344744
# [449]	valid_0's binary_logloss: 0.00344768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	valid_0's binary_logloss: 0.0034483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	valid_0's binary_logloss: 0.00344756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's binary_logloss: 0.00344834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's binary_logloss: 0.00344821
# [454]	valid_0's binary_logloss: 0.00344743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [455]	valid_0's binary_logloss: 0.00344815
# [456]	valid_0's binary_logloss: 0.00344827
# [457]	valid_0's binary_logloss: 0.00344852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's binary_logloss: 0.00344926
# [459]	valid_0's binary_logloss: 0.00344978
# [460]	valid_0's binary_logloss: 0.00345011
# [461]	valid_0's binary_logloss: 0.00345066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	valid_0's binary_logloss: 0.0034514
# [463]	valid_0's binary_logloss: 0.00345237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [464]	valid_0's binary_logloss: 0.00345165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [465]	valid_0's binary_logloss: 0.0034524
# [466]	valid_0's binary_logloss: 0.0034531
# [467]	valid_0's binary_logloss: 0.00345377
# [468]	valid_0's binary_logloss: 0.00345369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [469]	valid_0's binary_logloss: 0.00345303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	valid_0's binary_logloss: 0.00345363
# [471]	valid_0's binary_logloss: 0.00345388
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [472]	valid_0's binary_logloss: 0.00345515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [473]	valid_0's binary_logloss: 0.00345447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [474]	valid_0's binary_logloss: 0.00345511
# [475]	valid_0's binary_logloss: 0.00345549
# [476]	valid_0's binary_logloss: 0.00345577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	valid_0's binary_logloss: 0.00345514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [478]	valid_0's binary_logloss: 0.00345571
# [479]	valid_0's binary_logloss: 0.00345631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	valid_0's binary_logloss: 0.00345638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [481]	valid_0's binary_logloss: 0.00345701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	valid_0's binary_logloss: 0.00345725
# [483]	valid_0's binary_logloss: 0.00345689
# [484]	valid_0's binary_logloss: 0.00345817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [485]	valid_0's binary_logloss: 0.00345889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	valid_0's binary_logloss: 0.00346018
# [487]	valid_0's binary_logloss: 0.00345857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [488]	valid_0's binary_logloss: 0.00345801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's binary_logloss: 0.00345853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	valid_0's binary_logloss: 0.00345878
# [491]	valid_0's binary_logloss: 0.00345861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [492]	valid_0's binary_logloss: 0.00345927
# [493]	valid_0's binary_logloss: 0.00345976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [494]	valid_0's binary_logloss: 0.00346003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [495]	valid_0's binary_logloss: 0.00346076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [496]	valid_0's binary_logloss: 0.00346207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	valid_0's binary_logloss: 0.00346155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	valid_0's binary_logloss: 0.00346137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	valid_0's binary_logloss: 0.0034621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	valid_0's binary_logloss: 0.00346283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	valid_0's binary_logloss: 0.00346313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	valid_0's binary_logloss: 0.00346417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	valid_0's binary_logloss: 0.00346489
# [504]	valid_0's binary_logloss: 0.00346361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [505]	valid_0's binary_logloss: 0.00346387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	valid_0's binary_logloss: 0.00346342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	valid_0's binary_logloss: 0.0034639
# Early stopping, best iteration is:
# [307]	valid_0's binary_logloss: 0.00338665
# Training Log Loss:  0.0011061606514457536
# CV Log Loss:  0.003386647631002877
# Ensemble Log Loss:  0.0028603949586216582

# %%
print('Feature importances:', list(gbm.feature_importance()))
# Out:
# Feature importances: [125, 116, 69, 67, 163, 59, 59, 162, 162, 66, 144, 64, 125, 93, 352, 44, 104, 34, 31, 237, 57, 83, 186, 109, 95, 190, 199, 45, 107, 290, 145, 284, 411]

# %%
preds = pd.concat([y_train,predictionsBasedOnKFoldsEnsemble.loc[:,'prediction']], axis=1)
preds.columns = ['trueLabel','prediction']

precision, recall, thresholds = \
    precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = \
    average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(
          average_precision))

fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: \
Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
scatterData = predictionsTestSetLightGBMGradientBoosting.join(y_test,how='left')
scatterData.columns = ['Predicted Probability','True Label']
ax = sns.regplot(x="True Label", y="Predicted Probability", color='k',
                 fit_reg=False, scatter_kws={'alpha':0.1},
                 data=scatterData).set_title( \
                'Plot of Prediction Probabilities and the True Label')

# %%
scatterDataMelted = pd.melt(scatterData, "True Label", \
                            var_name="Predicted Probability")
scatterDataMelted.head()
ax = sns.stripplot(x="value", y="Predicted Probability", \
                   hue='True Label', jitter=0.4, \
                   data=scatterDataMelted).set_title( \
                   'Plot of Prediction Probabilities and the True Label')

# %%
# Pipeline for New Data
# first, import new data into a dataframe called 'newData'
# second, scale data
# newData.loc[:,featuresToScale] = sX.transform(newData[featuresToScale])
# third, predict using LightGBM
# gbm.predict(newData, num_iteration=gbm.best_iteration)
